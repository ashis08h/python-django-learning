# %%
import pandas as pd

# %%
df = pd.read_csv('data_folder/nyc_weather.csv')

# %%
df
# Out:
#         EST  Temprature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01/01/16          38        23        52                 30.03
# 1  01/02/16          36        18        46                 30.02
# 2  01/03/16          40        21        47                 29.86
# 3  01/04/16          25         9        44                 30.05
# 4  01/05/16          20        -3        41                 30.57
# 5  01/06/16          33         4        35                 30.50
# 6  01/07/16          35         3        29                 30.09
#
#    VisibilityMile  WindSpeedMPH  PrecipitationIn  CloudCover Events  \
# 0              10           8.0                0           5    NaN
# 1              10           7.0                0           3    NaN
# 2              10           8.0                0           1    NaN
# 3              10           9.0                0           3   Rain
# 4              10           5.0                0           0    NaN
# ...

# %%
# What is the maximum temprature
df['Temprature'].max()
# Out:
# 40

# %%
# The date on which rain happened.
df['EST'][df['Events']=='Rain']
# Out:
# 3    01/04/16
# 5    01/06/16
# Name: EST, dtype: object

# %%
# data frame where there is no rain.
df[df['Events'].isna()]
# Out:
#         EST  Temprature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01/01/16          38        23        52                 30.03
# 1  01/02/16          36        18        46                 30.02
# 2  01/03/16          40        21        47                 29.86
# 4  01/05/16          20        -3        41                 30.57
# 6  01/07/16          35         3        29                 30.09
#
#    VisibilityMile  WindSpeedMPH  PrecipitationIn  CloudCover Events  \
# 0              10           8.0                0           5    NaN
# 1              10           7.0                0           3    NaN
# 2              10           8.0                0           1    NaN
# 4              10           5.0                0           0    NaN
# 6              10           NaN                0           4    NaN
#
#    WindDirDegree
# 0            281
# 1            275
# 2            277
# 4            333
# 6            345

# %%
# What is my average windspeed
df['WindSpeedMPH'].mean()
# Out:
# 6.833333333333333

# %%
#Fill na value with some numbers.
df['WindSpeedMPH'].fillna(0, inplace=True)

# %%
df
# Out:
#         EST  Temprature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01/01/16          38        23        52                 30.03
# 1  01/02/16          36        18        46                 30.02
# 2  01/03/16          40        21        47                 29.86
# 3  01/04/16          25         9        44                 30.05
# 4  01/05/16          20        -3        41                 30.57
# 5  01/06/16          33         4        35                 30.50
# 6  01/07/16          35         3        29                 30.09
#
#    VisibilityMile  WindSpeedMPH  PrecipitationIn  CloudCover Events  \
# 0              10           8.0                0           5    NaN
# 1              10           7.0                0           3    NaN
# 2              10           8.0                0           1    NaN
# 3              10           9.0                0           3   Rain
# 4              10           5.0                0           0    NaN
# ...

# %%
df['WindSpeedMPH'].mean()
# Out:
# 5.857142857142857
